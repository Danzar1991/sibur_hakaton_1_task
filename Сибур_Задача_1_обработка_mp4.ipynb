# %% [markdown]
# #Решение задачи классификации набора видеороликов, каждый из которых относится к одному из четырех классов с помощью градиентного бустинга из библиотеки catboost

# %% [markdown]
# https://drive.google.com/file/d/1i8RkwwnQ0vzkuNIBLlsLeYi29vsyo5Hs/view?usp=sharing

# %% [markdown]
# Загрузим архив с видеороликами с гугл диска

# %%
! gdown --id 1i8RkwwnQ0vzkuNIBLlsLeYi29vsyo5Hs
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1i8RkwwnQ0vzkuNIBLlsLeYi29vsyo5Hs
# To: /content/train_sibur_1task.zip
# 100% 56.0M/56.0M [00:00<00:00, 69.3MB/s]

# %% [markdown]
# Распакуем загруженный архив

# %%
! unzip /content/train_sibur_1task.zip
# Out:
# Archive:  /content/train_sibur_1task.zip
#    creating: bridge_down/
#   inflating: bridge_down/e5f35a69b5fdde5a.mp4
#   inflating: bridge_down/b0b2e92153ee21f3.mp4
#   inflating: bridge_down/0a9d37c222ccce4a.mp4
#   inflating: bridge_down/0cbedb20b827e285.mp4
#   inflating: bridge_down/354914dca502d24e.mp4
#   inflating: bridge_down/9b38da83fc283459.mp4
#   inflating: bridge_down/c98b9d9ce7d20c67.mp4
#   inflating: bridge_down/65e1f3ca7f161cf3.mp4
#   inflating: bridge_down/47f02ea5b361b905.mp4
#   inflating: bridge_down/78988e7b0fa6d3b6.mp4
#   inflating: bridge_down/84440a85bdcda906.mp4
#   inflating: bridge_down/100816388bee023c.mp4
#   inflating: bridge_down/5f1fc70dd930375f.mp4
#   inflating: bridge_down/2a5e4a3cddf72998.mp4
#   inflating: bridge_down/ab9dfd1072d4e259.mp4
#   inflating: bridge_down/790296a321decd6b.mp4
#   inflating: bridge_down/3884f8809fe08a41.mp4
#   inflating: bridge_down/efa044318bc83065.mp4
#   inflating: bridge_down/6edfb18ca69cae9c.mp4
#   inflating: bridge_down/97d3ecee145d3a24.mp4
#   inflating: bridge_down/73a1faf318940cd1.mp4
#   inflating: bridge_down/7af9cc14efbcc561.mp4
#   inflating: bridge_down/dc0d9773a9a35920.mp4
#   inflating: bridge_down/0d46339066ad7a37.mp4
#   inflating: bridge_down/399f54c8c028792e.mp4
#   inflating: bridge_down/2237d8df2d0c422d.mp4
#   inflating: bridge_down/3fbce3dfd8e2500a.mp4
#   inflating: bridge_down/b7dd85c433610401.mp4
#   inflating: bridge_down/57e5795b1672d2f7.mp4
#   inflating: bridge_down/da9a581ae5a4f723.mp4
#   inflating: bridge_down/7ae945d231190aad.mp4
#   inflating: bridge_down/9100c3a5b86bc13d.mp4
#   inflating: bridge_down/a10a5dbbca9f6b33.mp4
#   inflating: bridge_down/cee1d552e1285c78.mp4
#   inflating: bridge_down/2a7fd7cb74f147b0.mp4
#   inflating: bridge_down/224db4f02d9e979c.mp4
#   inflating: bridge_down/c3b21562c07ab15d.mp4
#   inflating: bridge_down/09f549920471d0c4.mp4
#   inflating: bridge_down/38effb969f077cbf.mp4
#   inflating: bridge_down/7158a58ce20fb3de.mp4
#   inflating: bridge_down/dffb7b1985277aee.mp4
#   inflating: bridge_down/e44d7ed091259254.mp4
#   inflating: bridge_down/b024430fcc3ebfcf.mp4
#   inflating: bridge_down/c0a96c60c026fb6c.mp4
#   inflating: bridge_down/de2d8042159e494e.mp4
#   inflating: bridge_down/577df397611cf703.mp4
#   inflating: bridge_down/f3712d7e90067dfb.mp4
#   inflating: bridge_down/31527bc5b20de802.mp4
#   inflating: bridge_down/1721e6d328fc0cd2.mp4
#   inflating: bridge_down/9e99a661e7a8cd04.mp4
#   inflating: bridge_down/0bec0c9f7c8a2f05.mp4
#   inflating: bridge_down/1432bba4b8421e0b.mp4
#   inflating: bridge_down/7db2903b164ed571.mp4
#   inflating: bridge_down/39e219921d3535e4.mp4
#   inflating: bridge_down/fbf637f4c5536414.mp4
#   inflating: bridge_down/ec45a34226c4d731.mp4
#   inflating: bridge_down/06d725e724a8928a.mp4
#   inflating: bridge_down/40d09f5c9e3f073c.mp4
#   inflating: bridge_down/f041d39d6560d650.mp4
#   inflating: bridge_down/462ce800d75fb407.mp4
#   inflating: bridge_down/d0935649e08fb892.mp4
#   inflating: bridge_down/c80c3de7fddb2847.mp4
#   inflating: bridge_down/daf08381191561aa.mp4
#   inflating: bridge_down/b1efa6bf47b161c0.mp4
#   inflating: bridge_down/4077437dc447f168.mp4
#   inflating: bridge_down/3bd5392e32c0d317.mp4
#   inflating: bridge_down/88dbbe974771c6e1.mp4
#   inflating: bridge_down/470585b260d3ef77.mp4
#   inflating: bridge_down/01d6c9ecf3ed9c21.mp4
#   inflating: bridge_down/2612a9e07f596777.mp4
#   inflating: bridge_down/d5f116cebb515b51.mp4
#   inflating: bridge_down/de58f27c7908a4d9.mp4
#   inflating: bridge_down/790f22429c3b917a.mp4
#   inflating: bridge_down/4647d4a97ffeb55b.mp4
#   inflating: bridge_down/86b88217582dc8c3.mp4
#   inflating: bridge_down/ae295de15f8358bb.mp4
#   inflating: bridge_down/d151e21e9ec252dd.mp4
#   inflating: bridge_down/88c00402cdad6b36.mp4
#   inflating: bridge_down/d530cc531a54047e.mp4
#   inflating: bridge_down/f5ef245467aca596.mp4
#   inflating: bridge_down/a96b1b30e77eac27.mp4
#   inflating: bridge_down/0a004c8a0023a284.mp4
#   inflating: bridge_down/386940f86fe9d645.mp4
#   inflating: bridge_down/e5e3bb8bab61bfb3.mp4
#   inflating: bridge_down/07ccf1dcc457a22a.mp4
#   inflating: bridge_down/666a9999ce95fabf.mp4
#   inflating: bridge_down/1356a9e2f951a69d.mp4
#   inflating: bridge_down/c19cde386948c32c.mp4
#   inflating: bridge_down/f81fe44e70512516.mp4
#   inflating: bridge_down/258138cc5a3be54a.mp4
#   inflating: bridge_down/08e4c533f1d56db9.mp4
#   inflating: bridge_down/dbf1253a08c5cd09.mp4
#   inflating: bridge_down/c70f3ea7e16767db.mp4
#   inflating: bridge_down/d1d44770c35ccd4d.mp4
#   inflating: bridge_down/5ffa787ca9989f47.mp4
#   inflating: bridge_down/9d50e44b89966e27.mp4
#   inflating: bridge_down/e39dd3bbe2d19281.mp4
#   inflating: bridge_down/4c84412160ec1c9d.mp4
#   inflating: bridge_down/7d407600e6edcc62.mp4
#   inflating: bridge_down/a1321daa20490dbf.mp4
#   inflating: bridge_down/7f5d1904011f9bb1.mp4
#   inflating: bridge_down/ae6fa1f1252da9ad.mp4
#   inflating: bridge_down/05a2f0b1101a474a.mp4
#   inflating: bridge_down/c775e7c5a068f5ec.mp4
#   inflating: bridge_down/29152ba118cee04e.mp4
#   inflating: bridge_down/2bb4d1d30e360a6e.mp4
#   inflating: bridge_down/4ad9d1894a83c9b7.mp4
#   inflating: bridge_down/fd39f2310c767b93.mp4
#   inflating: bridge_down/3cd681bd6e71d6da.mp4
#   inflating: bridge_down/0fb85ca2b19859f6.mp4
#   inflating: bridge_down/7dd3c1033fdd2acb.mp4
#   inflating: bridge_down/a5e5d1847d3d4bdc.mp4
#   inflating: bridge_down/e4a388436e99aee9.mp4
#   inflating: bridge_down/f1cd4507cf18ab7d.mp4
#   inflating: bridge_down/26cb03b8cfda1591.mp4
#   inflating: bridge_down/c03ca3bcaeec79c7.mp4
#   inflating: bridge_down/56f9682ba0d0158a.mp4
#   inflating: bridge_down/2ae7e6ca916f6b9d.mp4
#   inflating: bridge_down/01a9dd89287598bb.mp4
#   inflating: bridge_down/c19a602aa220c87d.mp4
#   inflating: bridge_down/709ef762931bd76c.mp4
#   inflating: bridge_down/313dc957c6990d2f.mp4
#   inflating: bridge_down/b477442be8238590.mp4
#   inflating: bridge_down/3a976d3d906f5358.mp4
#   inflating: bridge_down/d3d1726038d0bfb2.mp4
#   inflating: bridge_down/611a989fdd78c188.mp4
#   inflating: bridge_down/2848ff501b75dd18.mp4
#   inflating: bridge_down/4448c449ff59afcd.mp4
#   inflating: bridge_down/92848c13f18c8442.mp4
#   inflating: bridge_down/b9ebea76508e3437.mp4
#   inflating: bridge_down/cadf5770f510e985.mp4
#   inflating: bridge_down/97e73edef40b6a88.mp4
#   inflating: bridge_down/30974c2ddd8838d1.mp4
#   inflating: bridge_down/387f072f911d7d21.mp4
#   inflating: bridge_down/f6c452bc03a9abfc.mp4
#   inflating: bridge_down/b25c26b1ebf95ca7.mp4
#   inflating: bridge_down/b3939a5cec54e360.mp4
#   inflating: bridge_down/b6dc936535f382c2.mp4
#   inflating: bridge_down/67f2ef6e74a93504.mp4
#   inflating: bridge_down/660cacd15039a561.mp4
#   inflating: bridge_down/172b3e8ba510c898.mp4
#   inflating: bridge_down/32879d6b188bcf4b.mp4
#   inflating: bridge_down/a3416b7bf6cfdbc3.mp4
#   inflating: bridge_down/212d75e541529e72.mp4
#   inflating: bridge_down/cd647270a3a73cc1.mp4
#   inflating: bridge_down/435df1a47eea05f8.mp4
#   inflating: bridge_down/0f3206c95e98c59a.mp4
#   inflating: bridge_down/d4993421ab473491.mp4
#   inflating: bridge_down/ac88cb9cd5000d16.mp4
#   inflating: bridge_down/cca3a1c36a9e7f36.mp4
#   inflating: bridge_down/3278dcbb1c13dce1.mp4
#   inflating: bridge_down/f483e6a3df76dac7.mp4
#   inflating: bridge_down/faa83fc020c8b866.mp4
#   inflating: bridge_down/c06da46c22a4d6ab.mp4
#   inflating: bridge_down/745e4c4d7c85e882.mp4
#   inflating: bridge_down/59867be7dbd8437d.mp4
#   inflating: bridge_down/ca3557e870109ef0.mp4
#   inflating: bridge_down/67f1dd5714c3b98e.mp4
#   inflating: bridge_down/d1a33fd0f3765a63.mp4
#   inflating: bridge_down/b3b2ace30e12d6ee.mp4
#   inflating: bridge_down/a0c34c4c50b3e121.mp4
#   inflating: bridge_down/701a5f86a8306a33.mp4
#   inflating: bridge_down/0a067d726aba2db6.mp4
#   inflating: bridge_down/41a75204928ed63a.mp4
#   inflating: bridge_down/ea5f0548a0c1f262.mp4
#   inflating: bridge_down/57992818ebe361ac.mp4
#   inflating: bridge_down/d63375873edd7729.mp4
#   inflating: bridge_down/0f4a1345ccf0bc81.mp4
#   inflating: bridge_down/099cf6cd342bf8c5.mp4
#   inflating: bridge_down/73297e384cf9b2b0.mp4
#   inflating: bridge_down/5a4bacee9540ca8d.mp4
#   inflating: bridge_down/b2361c49e38c3b62.mp4
#   inflating: bridge_down/519374929a8f93b3.mp4
#   inflating: bridge_down/c8ae896654aedc03.mp4
#   inflating: bridge_down/cad21a4cfe064192.mp4
#   inflating: bridge_down/83582c0ecf51717e.mp4
#   inflating: bridge_down/5d37403173c24460.mp4
#   inflating: bridge_down/d606865a8dce4179.mp4
#   inflating: bridge_down/24307c3e9174333a.mp4
#   inflating: bridge_down/483366b32404c4e7.mp4
#   inflating: bridge_down/9f2298fce2c82f62.mp4
#   inflating: bridge_down/60da83fe0bb454bf.mp4
#   inflating: bridge_down/b1999ea316ea6476.mp4
#   inflating: bridge_down/d217256b3ff40227.mp4
#   inflating: bridge_down/8a5bc5459e1b24db.mp4
#   inflating: bridge_down/ba7817a91db9c6cb.mp4
#   inflating: bridge_down/4bb99c6dc46a9f7f.mp4
#   inflating: bridge_down/73b62cb483e9f2d7.mp4
#   inflating: bridge_down/6c877ac80836d18d.mp4
#   inflating: bridge_down/65919f83189c5b84.mp4
#   inflating: bridge_down/0b524a593c4b012d.mp4
#   inflating: bridge_down/0894945545d363c8.mp4
#   inflating: bridge_down/4429f491d8800d9a.mp4
#   inflating: bridge_down/55d55c7f4eabc7b0.mp4
#   inflating: bridge_down/09d889aa5ce5b662.mp4
#   inflating: bridge_down/61bd615d2a7bfd07.mp4
#   inflating: bridge_down/9109ce750de25c90.mp4
#   inflating: bridge_down/0cb6de4a1147def0.mp4
#   inflating: bridge_down/c64abea2d2437470.mp4
#   inflating: bridge_down/281049c9d161da8b.mp4
#   inflating: bridge_down/59329fb67c983c82.mp4
#   inflating: bridge_down/7656ebe62d0906bd.mp4
#   inflating: bridge_down/544d4349a8141fc9.mp4
#   inflating: bridge_down/a8766f6bd562a394.mp4
#   inflating: bridge_down/c03432d8c458375e.mp4
#   inflating: bridge_down/928cc9eaf2eb7590.mp4
#   inflating: bridge_down/0709b441fe34963b.mp4
#   inflating: bridge_down/9836bb677b7a6d28.mp4
#   inflating: bridge_down/631a4943bea75bd2.mp4
#   inflating: bridge_down/78ae93807a84e8d7.mp4
#   inflating: bridge_down/1b98537880b065ff.mp4
#   inflating: bridge_down/cf14bd3e5aeb5390.mp4
#   inflating: bridge_down/44f5d7ecbe7a0152.mp4
#   inflating: bridge_down/ee7889c1868fd8d2.mp4
#   inflating: bridge_down/166d7e253ba332c3.mp4
#   inflating: bridge_down/9e445dea6b141e8b.mp4
#   inflating: bridge_down/9165f293c1f64034.mp4
#   inflating: bridge_down/804837b1dd996275.mp4
#   inflating: bridge_down/77e7a40a011a280e.mp4
#   inflating: bridge_down/0b1c677c9abaca06.mp4
#   inflating: bridge_down/4e7421c353e9f23c.mp4
#   inflating: bridge_down/812e338b4e4f9fdf.mp4
#   inflating: bridge_down/c2c648ed7e58f2d1.mp4
#   inflating: bridge_down/a1e248f15302ae10.mp4
#   inflating: bridge_down/3fd3476e479517dc.mp4
#   inflating: bridge_down/60f4ba30ed3d860d.mp4
#   inflating: bridge_down/7b44966ffd9c9968.mp4
#   inflating: bridge_down/b3d0791003bcd2d8.mp4
#   inflating: bridge_down/db56afb747ac81e5.mp4
#   inflating: bridge_down/3e4ed739c679d5cb.mp4
#   inflating: bridge_down/028addb2431dbe90.mp4
#   inflating: bridge_down/b1c2cbd53908d729.mp4
#   inflating: bridge_down/5a94e49e35680638.mp4
#   inflating: bridge_down/f55bbf2bbb8703b1.mp4
#   inflating: bridge_down/62015efc44191539.mp4
#   inflating: bridge_down/780dd314b9749b06.mp4
#   inflating: bridge_down/35d19c7f40fb30c4.mp4
#   inflating: bridge_down/bb902f0eec95e7ab.mp4
#   inflating: bridge_down/d1059a3ea72ab216.mp4
#   inflating: bridge_down/5b9b376f466ee0ec.mp4
#   inflating: bridge_down/1544718dfaffcb59.mp4
#   inflating: bridge_down/3f624032f72f81f7.mp4
#   inflating: bridge_down/fa1f3f145b30f087.mp4
#   inflating: bridge_down/69ded836466f5617.mp4
#   inflating: bridge_down/8ef3022d28a97506.mp4
#   inflating: bridge_down/937b20a0648d6a5f.mp4
#   inflating: bridge_down/2ec9dc60f4814e45.mp4
#   inflating: bridge_down/fc049029a5ba8904.mp4
#   inflating: bridge_down/f8067c3214cfafa2.mp4
#   inflating: bridge_down/6023ca72e0848ad7.mp4
#   inflating: bridge_down/0f3354ab179f1756.mp4
#   inflating: bridge_down/1f0d30a273ca80fa.mp4
#   inflating: bridge_down/348229f309635ec1.mp4
#   inflating: bridge_down/22e7b2a24d70960a.mp4
#   inflating: bridge_down/1f6ae172b0d48608.mp4
#   inflating: bridge_down/d81775ce9385f628.mp4
#   inflating: bridge_down/fc4751070ae45dbd.mp4
#   inflating: bridge_down/07a267d061839a0c.mp4
#   inflating: bridge_down/2ed1d2e5c06d5472.mp4
#   inflating: bridge_down/1a62fa61482a0219.mp4
#   inflating: bridge_down/e4ef493ae83c108b.mp4
#   inflating: bridge_down/abd8f0e96bbe17be.mp4
#   inflating: bridge_down/3c6e818cbb7dcaf8.mp4
#   inflating: bridge_down/1a6e86934ac66269.mp4
#   inflating: bridge_down/c70806a97617529a.mp4
#   inflating: bridge_down/1b42cec0f0094e11.mp4
#   inflating: bridge_down/ae33df24bc79c858.mp4
#   inflating: bridge_down/cb97436e69121e2b.mp4
#   inflating: bridge_down/b9badc8dd567155f.mp4
#   inflating: bridge_down/e41f93bdfd05afd6.mp4
#   inflating: bridge_down/b81ee710796d5c3a.mp4
#   inflating: bridge_down/79bed5f7abb38f8d.mp4
#   inflating: bridge_down/4e9bc4bea0461f2b.mp4
#   inflating: bridge_down/ad0c39de8c27c64b.mp4
#   inflating: bridge_down/0b82fcfd71e2be60.mp4
#   inflating: bridge_down/d6be86768fa129b8.mp4
#   inflating: bridge_down/4d5c91343dfb7241.mp4
#   inflating: bridge_down/3010288723478f4e.mp4
#   inflating: bridge_down/cec7cf6fb6ac370b.mp4
#   inflating: bridge_down/c79622d8f23188fd.mp4
#   inflating: bridge_down/082144bb2989411c.mp4
#   inflating: bridge_down/5a8aa258f6a5dbe9.mp4
#   inflating: bridge_down/4d4c1f206138faae.mp4
#   inflating: bridge_down/5069a197ba0c7b90.mp4
#   inflating: bridge_down/997dace1de85dc3b.mp4
#   inflating: bridge_down/dcc7636e6b7b7ea1.mp4
#   inflating: bridge_down/21234d0b32e57405.mp4
#   inflating: bridge_down/c5090f1268bc9104.mp4
#   inflating: bridge_down/e4eff99726cb77d1.mp4
#   inflating: bridge_down/af861ce826a56c9e.mp4
#   inflating: bridge_down/ea1bf78e20cd4c63.mp4
#   inflating: bridge_down/443333970a7dece5.mp4
#   inflating: bridge_down/98861bd2978d75b6.mp4
#   inflating: bridge_down/3fa82143f031959f.mp4
#   inflating: bridge_down/fac67f4db51ba563.mp4
#   inflating: bridge_down/7de61bdc9d057b44.mp4
#   inflating: bridge_down/fafc061d753ff3e4.mp4
#   inflating: bridge_down/fc8f3566b1e8ef5c.mp4
#   inflating: bridge_down/82ee6e72fba8f1e1.mp4
#   inflating: bridge_down/38ee07c62e15a400.mp4
#   inflating: bridge_down/3c03522e730274a8.mp4
#   inflating: bridge_down/2c06b1caaaf1b869.mp4
#   inflating: bridge_down/fa47b56df3bdfa7c.mp4
#   inflating: bridge_down/1597a805f0d55280.mp4
#   inflating: bridge_down/01531ae3db6e8494.mp4
#   inflating: bridge_down/5e1d568a6c2dd787.mp4
#    creating: bridge_up/
#   inflating: bridge_up/870d3067ab534a57.mp4
#   inflating: bridge_up/130f590d9c8034c8.mp4
#   inflating: bridge_up/e15b70830c83ee2f.mp4
#   inflating: bridge_up/bbdb8f73a9022d81.mp4
#   inflating: bridge_up/92d0f18bad176695.mp4
#   inflating: bridge_up/09980a219eeb4268.mp4
#   inflating: bridge_up/e2a1b084fc73049f.mp4
#   inflating: bridge_up/29edd98ae0bc4e08.mp4
#   inflating: bridge_up/e603a7ca3b43cf23.mp4
#   inflating: bridge_up/5e6f43fb7efad2af.mp4
#   inflating: bridge_up/44eab345ff8956e6.mp4
#   inflating: bridge_up/cabd240c452498fa.mp4
#   inflating: bridge_up/d28e45d3c71083f2.mp4
#   inflating: bridge_up/88958dd4e1a5cc69.mp4
#   inflating: bridge_up/e3ef3988305378e2.mp4
#   inflating: bridge_up/bcd0b5a94bdfd8db.mp4
#   inflating: bridge_up/f056355f5b8e6b7d.mp4
#   inflating: bridge_up/7fc820eeaa742ac4.mp4
#   inflating: bridge_up/bd489c88a046af92.mp4
#   inflating: bridge_up/0709a815e5c94e23.mp4
#   inflating: bridge_up/a17d6f493042e9c1.mp4
#   inflating: bridge_up/8139c568a635c7c6.mp4
#   inflating: bridge_up/47b5eb98f2415596.mp4
#   inflating: bridge_up/31407f1d72d5d857.mp4
#   inflating: bridge_up/4d9db56a957eb9b6.mp4
#   inflating: bridge_up/eb92f0f94a082daa.mp4
#   inflating: bridge_up/74e366d08cd06039.mp4
#   inflating: bridge_up/25909753046415ff.mp4
#   inflating: bridge_up/e9dcb3adde46fcf0.mp4
#   inflating: bridge_up/8aacc08226d1c5a8.mp4
#   inflating: bridge_up/a9c45ad42e03a20a.mp4
#   inflating: bridge_up/b4aba7e191ad9de0.mp4
#   inflating: bridge_up/409aad57d084bc6e.mp4
#   inflating: bridge_up/ae60c15fd7e2cd3d.mp4
#   inflating: bridge_up/71c1d326794f7b48.mp4
#   inflating: bridge_up/255c69baaf885747.mp4
#   inflating: bridge_up/802ce0f6fcc32ecb.mp4
#   inflating: bridge_up/28532f70de3565c5.mp4
#   inflating: bridge_up/b0a1c5ddef4859a9.mp4
#   inflating: bridge_up/574bec3811e1965a.mp4
#   inflating: bridge_up/a3e42eb651728430.mp4
#   inflating: bridge_up/d992ba223a35b8a8.mp4
#   inflating: bridge_up/5eb3506565e9ff46.mp4
#   inflating: bridge_up/4ed2c51ffc172a03.mp4
#   inflating: bridge_up/a08510359964c8f9.mp4
#   inflating: bridge_up/009348946266095a.mp4
#   inflating: bridge_up/2e85823284fb273d.mp4
#   inflating: bridge_up/a536511a19c61e7b.mp4
#   inflating: bridge_up/78fcec67021ae65a.mp4
#   inflating: bridge_up/14931fce3c22084f.mp4
#   inflating: bridge_up/18f3d3849f49eb50.mp4
#   inflating: bridge_up/5bb806639d163766.mp4
#   inflating: bridge_up/2fae1112ce067a12.mp4
#   inflating: bridge_up/bf51d97e139398f6.mp4
#   inflating: bridge_up/bcf899f090675d0f.mp4
#   inflating: bridge_up/db19a33c9016c296.mp4
#   inflating: bridge_up/134f0e3814a13c42.mp4
#   inflating: bridge_up/5f7b53fefa0dd0c2.mp4
#   inflating: bridge_up/783f8d2262d25b15.mp4
#   inflating: bridge_up/3bc8ee63a519ab8b.mp4
#   inflating: bridge_up/0deae38596fcef18.mp4
#   inflating: bridge_up/1c13d07b6156a7bc.mp4
#   inflating: bridge_up/fc176bebf46d3f43.mp4
#   inflating: bridge_up/a547adde790d93ec.mp4
#   inflating: bridge_up/c940e627bcd1f137.mp4
#   inflating: bridge_up/14660a902804c492.mp4
#   inflating: bridge_up/61c5ae427509bc1d.mp4
#   inflating: bridge_up/03523b4960a0aa5f.mp4
#   inflating: bridge_up/0f0b303180728956.mp4
#   inflating: bridge_up/bf2e1c2c40b60146.mp4
#   inflating: bridge_up/98f55b2fffc83f9e.mp4
#   inflating: bridge_up/5f864ce5b3eb38c2.mp4
#   inflating: bridge_up/7854f9d7acd677ae.mp4
#   inflating: bridge_up/590524ffcf1dfa75.mp4
#   inflating: bridge_up/d7cbd916f72e71a1.mp4
#    creating: no_action/
#   inflating: no_action/bbca6fe746a74e94.mp4
#   inflating: no_action/42b9e817c0190acd.mp4
#   inflating: no_action/f8453516dcd84400.mp4
#   inflating: no_action/579c3b378df7c098.mp4
#   inflating: no_action/a3c3b83ed13097de.mp4
#   inflating: no_action/834f96e9ac49dc25.mp4
#   inflating: no_action/060fb2db9c860b66.mp4
#   inflating: no_action/7f20a690549ee780.mp4
#   inflating: no_action/2ba73f2af2fc40a9.mp4
#   inflating: no_action/3b8875d081288b97.mp4
#   inflating: no_action/53b1077b1729746f.mp4
#   inflating: no_action/8788d89c8bc19606.mp4
#   inflating: no_action/0f4c86beb84b2eca.mp4
#   inflating: no_action/3e6817c626df94fe.mp4
#   inflating: no_action/ac88034e85bb723b.mp4
#   inflating: no_action/fe75e1f7038e4fa8.mp4
#   inflating: no_action/c741aa8c36791a37.mp4
#   inflating: no_action/aa5175f038b8be3f.mp4
#   inflating: no_action/03b8033d6d547574.mp4
#   inflating: no_action/25736d9c2b514c8d.mp4
#   inflating: no_action/a7d3c11764d1bff5.mp4
#   inflating: no_action/d5a00c7fced2bcfd.mp4
#   inflating: no_action/b544059b980f4535.mp4
#   inflating: no_action/3b9048869928835f.mp4
#   inflating: no_action/77c7a5e6998b35e2.mp4
#   inflating: no_action/1df2cff51066ac34.mp4
#   inflating: no_action/359d8994e59bc4c2.mp4
#   inflating: no_action/a22dc2953e4fc949.mp4
#   inflating: no_action/d9ed8fc4e83d441c.mp4
#   inflating: no_action/94ef8340f6d675f3.mp4
#   inflating: no_action/cdb09e141f61b6e5.mp4
#   inflating: no_action/bf8aa6576663561b.mp4
#   inflating: no_action/54be7d16e67b50f5.mp4
#   inflating: no_action/a92d16fd3fa7da43.mp4
#   inflating: no_action/f0df489b60804efa.mp4
#   inflating: no_action/db6b7bfc03d8e720.mp4
#   inflating: no_action/8af8e2641f47d0c4.mp4
#   inflating: no_action/a9a1ae95de26b88f.mp4
#   inflating: no_action/26539a8b477368ac.mp4
#   inflating: no_action/48274dbbe29cc3c1.mp4
#   inflating: no_action/f8176db350e8e14a.mp4
#   inflating: no_action/a63b961ce65a6c06.mp4
#   inflating: no_action/1dd6bf94517609eb.mp4
#   inflating: no_action/4680e1a491f77263.mp4
#   inflating: no_action/8e514daeefda7dd7.mp4
#   inflating: no_action/42c2bda22052536c.mp4
#   inflating: no_action/5f64fa2034db489f.mp4
#   inflating: no_action/3f28190969779ef0.mp4
#   inflating: no_action/f9397b79bb605494.mp4
#    creating: train_in_out/
#   inflating: train_in_out/052b084edf435fd0.mp4
#   inflating: train_in_out/bb3f80126973704d.mp4
#   inflating: train_in_out/c1023971326eb67e.mp4
#   inflating: train_in_out/5879ba75b7023729.mp4
#   inflating: train_in_out/4fca1d1c23743300.mp4
#   inflating: train_in_out/83041a7e5370ccd1.mp4
#   inflating: train_in_out/167fbd4c45163b18.mp4
#   inflating: train_in_out/bca616c889f94f27.mp4
#   inflating: train_in_out/213e726906864e9c.mp4
#   inflating: train_in_out/b1f7d0affbba39aa.mp4
#   inflating: train_in_out/c75bc09b5b7bdc70.mp4
#   inflating: train_in_out/5e53e235164e5386.mp4
#   inflating: train_in_out/c0298f5943b73941.mp4
#   inflating: train_in_out/8ee29f289b85d33f.mp4
#   inflating: train_in_out/e5c8dc60bbd288ef.mp4
#   inflating: train_in_out/0e9cd57992d986ce.mp4
#   inflating: train_in_out/ba3cc89b7741693c.mp4
#   inflating: train_in_out/9f3ba81c4c6ffbd2.mp4
#   inflating: train_in_out/1e62763c669920b4.mp4
#   inflating: train_in_out/32afa0ba3020e09f.mp4
#   inflating: train_in_out/dfc0f7d52e2b6eed.mp4
#   inflating: train_in_out/1858c7dd10a1817d.mp4
#   inflating: train_in_out/b0dfec0651a7fcf9.mp4
#   inflating: train_in_out/fa37a03b72bd12b0.mp4
#   inflating: train_in_out/c1d65fcbf8376f0e.mp4
#   inflating: train_in_out/70bea1eeba6739df.mp4
#   inflating: train_in_out/6a810498689fad59.mp4
#   inflating: train_in_out/ac708a077b3003f0.mp4
#   inflating: train_in_out/088d91a5d5de25f4.mp4
#   inflating: train_in_out/5564ec76ba7dcc48.mp4
#   inflating: train_in_out/6b5e2a8b6ed185cb.mp4
#   inflating: train_in_out/1c155a4956168d21.mp4
#   inflating: train_in_out/6ffaf64a5172a8e8.mp4
#   inflating: train_in_out/ccc5f58aa6de100b.mp4
#   inflating: train_in_out/e47ae91189ce0e69.mp4
#   inflating: train_in_out/d5dd5393618e6946.mp4
#   inflating: train_in_out/09fb8c041fced8c3.mp4
#   inflating: train_in_out/e0351f88ed52db65.mp4
#   inflating: train_in_out/621b1a0f13b27229.mp4
#   inflating: train_in_out/24b468923c4ae72b.mp4
#   inflating: train_in_out/68c64df10445214a.mp4
#   inflating: train_in_out/e8a0f6f7f2c50a2c.mp4
#   inflating: train_in_out/b48ba537f6df6d66.mp4
#   inflating: train_in_out/1722443d154fd587.mp4
#   inflating: train_in_out/250454b3ddcbc06a.mp4
#   inflating: train_in_out/d1c4650144cc18be.mp4
#   inflating: train_in_out/fbdf51391f396341.mp4
#   inflating: train_in_out/2d84ca48e2c5d664.mp4
#   inflating: train_in_out/ad81d4095b639979.mp4
#   inflating: train_in_out/fe8f774e99637f63.mp4
#   inflating: train_in_out/a37a81829637dcd8.mp4
#   inflating: train_in_out/b6e27216146d8f01.mp4
#   inflating: train_in_out/a0b372fafb015a85.mp4
#   inflating: train_in_out/3fa81e76b90b7efd.mp4
#   inflating: train_in_out/b6daebf44ba81fd0.mp4
#   inflating: train_in_out/2ee79043d4122811.mp4
#   inflating: train_in_out/92ca045758418ed6.mp4
#   inflating: train_in_out/4e8e7d5b590f094f.mp4
#   inflating: train_in_out/6a4034c2a6ae3927.mp4
#   inflating: train_in_out/19812f99b20a1d2e.mp4
#   inflating: train_in_out/01f23640259240cf.mp4
#   inflating: train_in_out/15a80e7c7a533d3d.mp4
#   inflating: train_in_out/7b11b87dd010c638.mp4
#   inflating: train_in_out/d2987e35db4635c9.mp4
#   inflating: train_in_out/2ce08918cccbf9d0.mp4
#   inflating: train_in_out/05a6323e7ae06fe2.mp4

# %% [markdown]
# Загрузим необходимые библиотеки.

# %%
import cv2
import pandas as pd
import os
import numpy as np
import pathlib
import warnings
warnings.filterwarnings("ignore")

# %%
RS = 3984765

# %% [markdown]
# \обработаем каждую папку с файлами mp4 и и переведем его в датасет с картинками

# %%
labels = ["bridge_down", "bridge_up", "no_action", "train_in_out"]

# %%
train_clips = {"label":[], "fname": []}

for label in labels:
    path = '/content/'
    list_files = os.listdir(path+label)
    for file_name in list_files:
        train_clips['label'].append(label)
        train_clips['fname'].append(file_name)

train_clips = pd.DataFrame(train_clips)
train_clips
# Out:
#             label                 fname
# 0     bridge_down  98861bd2978d75b6.mp4
# 1     bridge_down  fa47b56df3bdfa7c.mp4
# 2     bridge_down  73297e384cf9b2b0.mp4
# 3     bridge_down  cca3a1c36a9e7f36.mp4
# 4     bridge_down  790296a321decd6b.mp4
# ..            ...                   ...
# 491  train_in_out  5564ec76ba7dcc48.mp4
# 492  train_in_out  15a80e7c7a533d3d.mp4
# 493  train_in_out  088d91a5d5de25f4.mp4
# 494  train_in_out  167fbd4c45163b18.mp4
# 495  train_in_out  052b084edf435fd0.mp4
#
# [496 rows x 2 columns]

# %% [markdown]
# Посмотрим сколько роликов каждого класса находится в датасете

# %%
train_clips.label.value_counts()
# Out:
# bridge_down     306
# bridge_up        75
# train_in_out     66
# no_action        49
# Name: label, dtype: int64

# %% [markdown]
# Набор данных не сбалансирован

# %% [markdown]
# Напишем функцию, которая будет делать расскадровку видеороликов

# %%
def read_clip(odir: pathlib.Path, fname: str, start: int = 0, transposed: bool = True):
    """Прочесть ролик в массив."""

    cpr = cv2.VideoCapture(odir.joinpath(fname).as_posix())
    has_frame = True
    frames = []

    while has_frame:
        has_frame, frame = cpr.read()
        if has_frame:
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            if transposed:
                frame = np.moveaxis(frame, -1, 0).copy()

            frames.append(frame)
    cpr.release()
    return np.array(frames)[start:]

# %% [markdown]
# С помощью претренированной модели извлечём признаки для каждого кадра,
# посчитаем среднее значение для всего ролика,
# натренируем простую модель на полученных признаках.
# Для извлечения признаков используем какую-либо из моделей, доступных в TensorFlow Hub.
# Для ускорения будем уменьшать изображения до 96 x 96:

# %%
import tensorflow as tf
import tensorflow_hub as hub
fts_extract = tf.keras.Sequential([
    tf.keras.layers.Resizing(96, 96, interpolation="bilinear"),
    tf.keras.layers.Rescaling(scale=1.0 / 127.5, offset=-1),
    hub.KerasLayer("https://tfhub.dev/google/imagenet/mobilenet_v2_100_96/feature_vector/5", trainable=False)
])
fts_extract.build([None, 240, 320, 3])

# %% [markdown]
# У нас всего 496 роликов, поэтому 1280 признаков нам не нужны (и избыточны). Однако и нормально провести dimensionality reduction при таком количестве признаков тоже непросто. Поэтому сделаем random projection:

# %%
from sklearn.random_projection import GaussianRandomProjection

# %%
from sklearn.model_selection import train_test_split
projector = GaussianRandomProjection(n_components=50, random_state=RS)
projector.fit(np.random.rand(10, 1280))
# Out:
# GaussianRandomProjection(n_components=50, random_state=3984765)

# %%
import tqdm
DATA_DIR = pathlib.Path("")

# %% [markdown]
# Вытащим признаки из набора видеороликов, предварительно сделав раскадровку с помощью функции read_clip, представленной выше:

# %%
features = []
for ci, row in tqdm.tqdm(train_clips.iterrows(), total=train_clips.shape[0]):
    clip = read_clip(DATA_DIR.joinpath("/content/", row.label), row.fname, transposed=False)
    outputs = fts_extract(clip)
    features.append(projector.transform(outputs.numpy()).mean(axis=0))
# Out:
# 100%|██████████| 496/496 [17:48<00:00,  2.15s/it]

# %%
features = np.vstack(features)

# %% [markdown]
# Соберем признаки в DataFrame

# %%
df = pd.DataFrame(features, index=train_clips.index, columns=[f"fts{i}" for i in range(features.shape[1])])
df
# Out:
#           fts0      fts1       fts2      fts3      fts4      fts5      fts6  \
# 0    -2.549675 -0.761511   0.439506 -2.572969 -7.088608 -5.110124 -1.561289
# 1    -2.267458  1.841458   8.713071  1.015860 -6.367874  2.607790 -1.218254
# 2     1.359956 -3.710513   8.610892 -0.828716 -2.725628 -5.660552 -6.859534
# 3    -2.489228 -4.238406   4.764355 -5.242531 -4.692200 -4.000678 -5.828839
# 4     5.789810 -4.875088   5.849388 -3.530506 -9.633269  1.122845 -6.887261
# ..         ...       ...        ...       ...       ...       ...       ...
# 491   7.755018 -5.064724   3.008095 -5.581529 -5.439809  0.805191 -3.075935
# 492  -2.637232 -4.088146   5.116719 -1.845585 -2.646413  1.156945  0.875141
# 493   9.476911 -5.390709   4.950569 -3.290462 -8.733536  2.628379 -0.649334
# 494  10.443397 -8.519401   5.307245  0.881264 -0.804222  3.138812 -2.891654
# 495   8.342863 -9.015200  10.972686 -0.667044 -4.259223 -0.721898 -3.981054
#
#          fts7      fts8      fts9  ...     fts40     fts41     fts42  \
# 0   -4.117859  5.731224 -3.939584  ...  4.973745  5.138914  1.962427
# 1   -2.096806  2.053915  4.249879  ...  4.374151  6.049245 -1.376278
# 2    1.537932  8.448419 -2.828681  ...  2.131435  6.845980 -0.725789
# 3    1.254182  3.792231 -0.010511  ... -0.696800  3.659305 -2.648019
# 4    4.212868 -0.623483 -1.036255  ...  0.218073 -1.265042 -4.009845
# ..        ...       ...       ...  ...       ...       ...       ...
# 491 -1.228055  6.822593 -0.247532  ...  5.699385  0.838541 -3.403297
# 492  2.804753  6.853201 -1.861731  ... -6.604254  6.688292 -0.755443
# 493  1.401924  4.197980 -1.301183  ...  8.366649  1.493234 -3.585271
# 494  1.427912  2.523178  0.418698  ...  0.076511 -3.150720 -3.864765
# 495 -3.888385  6.460945  6.027747  ... -3.834815  1.007934 -6.691912
#
#         fts43     fts44     fts45      fts46     fts47      fts48     fts49
# 0    3.440993  2.735537  7.284228   0.259979  1.769667  10.133673  0.771189
# 1   -0.558588  0.103114  6.474805   4.923724 -0.269710   7.037655  2.638213
# 2   -4.082477  5.229553  3.871656  12.051599 -1.527519   8.983080  0.723137
# 3   -0.819664  6.144162  1.545190   9.141098 -2.119478   6.135501  3.167746
# 4   -0.778813  2.452328  4.310110   7.055913 -1.846539   1.614427 -5.178898
# ..        ...       ...       ...        ...       ...        ...       ...
# 491 -1.557353  2.812439  4.900637   9.102808 -2.594538   2.831916  1.811559
# 492 -1.820704  6.673156  2.860103  -0.651445 -5.604997   5.850603 -1.029724
# 493  2.443919  2.912973  5.418749  12.082981 -3.480458   5.610549  0.279700
# 494 -2.425451  6.007544  4.089101   3.805128 -6.297423  -1.903657  2.106141
# 495 -2.620427  7.097957  4.273101   2.260544 -8.455509   0.398012  3.617215
#
# [496 rows x 50 columns]

# %% [markdown]
# Соединим по индексам полученный датафрейм с train_clips

# %%
joined_df = pd.concat([train_clips, df], axis=1)
df = joined_df.iloc[:, :]
df.head()
# Out:
#          label                 fname      fts0      fts1      fts2      fts3  \
# 0  bridge_down  98861bd2978d75b6.mp4 -2.549675 -0.761511  0.439506 -2.572969
# 1  bridge_down  fa47b56df3bdfa7c.mp4 -2.267458  1.841458  8.713071  1.015860
# 2  bridge_down  73297e384cf9b2b0.mp4  1.359956 -3.710513  8.610892 -0.828716
# 3  bridge_down  cca3a1c36a9e7f36.mp4 -2.489228 -4.238406  4.764355 -5.242531
# 4  bridge_down  790296a321decd6b.mp4  5.789810 -4.875088  5.849388 -3.530506
#
#        fts4      fts5      fts6      fts7  ...     fts40     fts41     fts42  \
# 0 -7.088608 -5.110124 -1.561289 -4.117859  ...  4.973745  5.138914  1.962427
# 1 -6.367874  2.607790 -1.218254 -2.096806  ...  4.374151  6.049245 -1.376278
# 2 -2.725628 -5.660552 -6.859534  1.537932  ...  2.131435  6.845980 -0.725789
# 3 -4.692200 -4.000678 -5.828839  1.254182  ... -0.696800  3.659305 -2.648019
# 4 -9.633269  1.122845 -6.887261  4.212868  ...  0.218073 -1.265042 -4.009845
#
#       fts43     fts44     fts45      fts46     fts47      fts48     fts49
# 0  3.440993  2.735537  7.284228   0.259979  1.769667  10.133673  0.771189
# 1 -0.558588  0.103114  6.474805   4.923724 -0.269710   7.037655  2.638213
# 2 -4.082477  5.229553  3.871656  12.051599 -1.527519   8.983080  0.723137
# 3 -0.819664  6.144162  1.545190   9.141098 -2.119478   6.135501  3.167746
# 4 -0.778813  2.452328  4.310110   7.055913 -1.846539   1.614427 -5.178898
#
# [5 rows x 52 columns]

# %% [markdown]
# Разделим данные на X и y

# %%
X = df.filter(like="fts")
y = df.label

# %% [markdown]
# Разделим выборку на тренировочную и валидационную

# %%
X_tr, X_val, y_tr, y_val = train_test_split(X, y,
                                                    test_size=0.2, random_state=RS)

# %% [markdown]
# Установим библиотеку catboost

# %%
# !pip install catboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting catboost
#   Downloading catboost-1.2-cp310-cp310-manylinux2014_x86_64.whl (98.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.22.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2022.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.2)
# Installing collected packages: catboost
# Successfully installed catboost-1.2

# %% [markdown]
# Будем использовать градиентный бустинг, поскольку во многих случаях он позволяет получить хорошие показатели даже без оптимизации модели. Попробуем натренировать CatBoostClassifier на этих признаках.

# %%
from catboost import CatBoostClassifier

# %%
from sklearn.metrics import f1_score, classification_report

# %%
cb_model = CatBoostClassifier(max_depth=4, iterations=1000, objective = 'MultiClass', verbose=200, eval_metric = 'TotalF1',
                                 random_state=RS)
cb_model.fit(X_tr, y_tr, eval_set=(X_val, y_val))
val_preds = cb_model.predict(X_val)
print(classification_report(y_val, val_preds))
# Out:
# Learning rate set to 0.105994
# 0:	learn: 0.6287545	test: 0.5731905	best: 0.5731905 (0)	total: 14.2ms	remaining: 14.1s
# 200:	learn: 0.9949138	test: 0.8108190	best: 0.8108190 (177)	total: 3.69s	remaining: 14.7s
# 400:	learn: 1.0000000	test: 0.8330718	best: 0.8330718 (224)	total: 5.92s	remaining: 8.85s
# 600:	learn: 1.0000000	test: 0.8338289	best: 0.8338289 (598)	total: 8.15s	remaining: 5.41s
# 800:	learn: 1.0000000	test: 0.8330718	best: 0.8439810 (662)	total: 10.4s	remaining: 2.58s
# 999:	learn: 1.0000000	test: 0.8439810	best: 0.8439810 (662)	total: 12.5s	remaining: 0us
#
# bestTest = 0.8439809524
# bestIteration = 662
#
# Shrink model to first 663 iterations.
#               precision    recall  f1-score   support
#
#  bridge_down       0.85      0.97      0.90        59
#    bridge_up       0.88      0.74      0.80        19
#    no_action       1.00      0.75      0.86         8
# train_in_out       0.73      0.57      0.64        14
#
#     accuracy                           0.85       100
#    macro avg       0.86      0.76      0.80       100
# weighted avg       0.85      0.85      0.84       100

# %% [markdown]
# Сохраним модель в файл

# %%
from joblib import dump, load
dump(cb_model, 'classifier-v1.joblib')
dump(projector, 'projector-v1.joblib')
# Out:
# ['projector-v1.joblib']

# %% [markdown]
# Подготовим сабмит и запишем файл предикт

# %%
# %%writefile predict.py

import pathlib
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
from joblib import load

PROJECTOR_FILE = pathlib.Path(__file__).parent.joinpath("projector-v1.joblib")
CLASSIFIER_FILE = pathlib.Path(__file__).parent.joinpath("classifier-v1.joblib")


def construct_model():
    fts_extract = tf.keras.Sequential([
        tf.keras.layers.Resizing(96, 96, interpolation="bilinear"),
        tf.keras.layers.Rescaling(scale=1.0 / 127.5, offset=-1),
        hub.KerasLayer("https://tfhub.dev/google/imagenet/mobilenet_v2_100_96/feature_vector/5", trainable=False)
    ])
    fts_extract.build([None, 240, 320, 3])
    return fts_extract


model = construct_model()
projector = load(PROJECTOR_FILE)
classifier = load(CLASSIFIER_FILE)


def predict(clip: np.ndarray):
    """Вычислить класс для этого клипа. Эта функция должна возвращать *имя* класса."""

    features = projector.transform(model(clip).numpy()).mean(axis=0, keepdims=True)
    return classifier.predict(features)[0]
# Out:
# Writing predict.py

# %% [markdown]
# Файл launch.json позволяет загрузить веса при сборке контейнера:

# %%
# %%writefile launch.json
# {
#     "torch": ["shufflenet_v2_x0_5"],
#     "tfhub": ["https://tfhub.dev/google/imagenet/mobilenet_v2_100_96/feature_vector/5"],
#     "transposed": false
# }
# Out:
# Writing launch.json

# %% [markdown]
# Запишем файл requirements.txt с версиями используемых библиотек.

# %%
# !pip3 freeze > requirements.txt
